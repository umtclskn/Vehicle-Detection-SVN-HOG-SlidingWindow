# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from utils.draw import *

# %%
image = mpimg.imread('inputs/sample1.jpg')

# %%
plt.figure(figsize=(18, 32))
plt.imshow(image)

# %%
# If you want to use your own image and cars' coordinates, 
# uncomment the block and select the corners of cars with double click and click the p for print the selected coordinate
'''
mouseX = 0.0
mouseY = 0.0
def draw_circle(event,x,y,flags,param):
    global mouseX,mouseY
    if event == cv2.EVENT_LBUTTONDBLCLK: # double click for getting selecting coordinates
        print("test")
        cv2.circle(image,(x,y),5,(255,0,0),-1)
        mouseX,mouseY = x,y

cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_circle)
while(1):
    cv2.imshow('image',image)
    k = cv2.waitKey(20) & 0xFF
    if k == 27:
        break
    elif k == ord('p'): #print the selected coordinates
        print(mouseX,mouseY)
cv2.destroyAllWindows()
'''
pass

# %%
human_eye_detected_cars = [((327, 777), (815, 482)), ((1138, 866), (1592, 535)), 
                           ((1604, 651), (1759, 525)) , ((1117, 580), (1214, 512)),
                           ((867, 650), (1111, 478))]

# %%
result = draw_boxes(image, human_eye_detected_cars)
plt.figure(figsize=(9, 16))
plt.imshow(result)
