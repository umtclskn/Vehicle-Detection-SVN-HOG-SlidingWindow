# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from utils.spatial_binning import resize

# %%
image = mpimg.imread('templates/temp5.jpg')

feature_vector = resize(image, size=(32, 32))

# "32*32*3" : width:32, height:32, RGB image channels count = 3
feature_vector.shape
# Out:
# (3072,)

# %%
plt.plot(feature_vector)
